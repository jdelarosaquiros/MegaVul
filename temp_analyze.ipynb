# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '../extracted_functions_with_calls.jsonl'

df = pd.read_json(file_path, lines=True)
df
# Out:
#                                        repo_url  \
# 0   https://issues.oss-fuzz.com/issues/42470537
# 1   https://issues.oss-fuzz.com/issues/42470537
# 2   https://issues.oss-fuzz.com/issues/42470537
# 3   https://issues.oss-fuzz.com/issues/42470537
# 4   https://issues.oss-fuzz.com/issues/42470537
# 5   https://issues.oss-fuzz.com/issues/42470537
# 6   https://issues.oss-fuzz.com/issues/42470537
# 7   https://issues.oss-fuzz.com/issues/42470537
# 8   https://issues.oss-fuzz.com/issues/42470537
# 9   https://issues.oss-fuzz.com/issues/42470537
# 10  https://issues.oss-fuzz.com/issues/42470537
# 11  https://issues.oss-fuzz.com/issues/42470537
# 12  https://issues.oss-fuzz.com/issues/42470537
# 13  https://issues.oss-fuzz.com/issues/42470537
# 14  https://issues.oss-fuzz.com/issues/42470537
# 15  https://issues.oss-fuzz.com/issues/42470537
# 16  https://issues.oss-fuzz.com/issues/42470537
# 17  https://issues.oss-fuzz.com/issues/42470537
# ...

# %%
df.loc[0]['callers']
# Out:
# [{'name': 'ssh_buffer_new',
#   'file_path': 'src/buffer.c',
#   'signature': '',
#   'return_type': 'struct ssh_buffer_struct',
#   'start_line': 119,
#   'end_line': 142,
#   'code': 'struct ssh_buffer_struct *ssh_buffer_new(void)\n{\n    struct ssh_buffer_struct *buf = NULL;\n    int rc;\n\n    buf = calloc(1, sizeof(struct ssh_buffer_struct));\n    if (buf == NULL) {\n        return NULL;\n    }\n\n    /*\n     * Always preallocate 64 bytes.\n     *\n     * -1 for ralloc_buffer magic.\n     */\n    rc = ssh_buffer_allocate_size(buf, 64 - 1);\n    if (rc != 0) {\n        SAFE_FREE(buf);\n        return NULL;\n    }\n    buffer_verify(buf);\n\n    return buf;\n}',
#   'call_line': 119},
#  {'name': 'ssh_buffer_free',
#   'file_path': 'src/buffer.c',
#   'signature': '(struct ssh_buffer_struct *buffer)',
#   'return_type': 'void',
#   'start_line': 149,
#   'end_line': 166,
# ...
